# %% [markdown]
# Project 3 : Regression Problem 1

# %%
# loading test and train csv files as test and train
import pandas as pd
train_data= pd.read_csv('C:/Users/Hema Chandran/anacond/pkgs/ipykernel-6.25.0-py311h746a85d_0/Lib/site-packages/finalproj/p1_train.csv') # read the csv file as a dataframe
test_data= pd.read_csv('C:/Users/Hema Chandran/anacond/pkgs/ipykernel-6.25.0-py311h746a85d_0/Lib/site-packages/finalproj/p1_test.csv') # read the csv file as a dataframe

print(train_data.shape)
print(test_data.shape)
# Out:
# (9999, 3)
# (4999, 3)

# %%
import numpy as np
import pandas as pd
from numpy import load
import pickle as pl

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
x=train_data.iloc[:,0] 
x1=train_data.iloc[:,1] 
y=train_data.iloc[:,2]
print(y)
x_test=test_data.iloc[:,0]
x1_test=test_data.iloc[:,1]
y1_test = test_data.iloc[:,2]
#print(x1_test)
#print(y1_test)
# Out:
# 0      -13.275822
# 1       31.815190
# 2        1.995030
# 3       48.812452
# 4       -0.481346
#           ...
# 9994   -21.776089
# 9995    22.098571
# 9996   -47.812604
# 9997    20.791085
# 9998   -20.735447
# Name: 5.358725498169498280e+00, Length: 9999, dtype: float64

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(x,x1,y, 'blue')
ax.set_title('3D line plot of biological sensors')
plt.show()

# %%
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
# creating feature variables 

X = train_data.drop('5.358725498169498280e+00',axis=1)
X1 = test_data.drop('-3.756792885773750612e+01',axis=1)
print(X1) 
print(X)
# Out:
#       1.589300268390259419e+01  1.171282902260990966e+01
# 0                    -2.722421                 -4.540615
# 1                   -14.587111                 18.592864
# 2                     0.224331                 16.433306
# 3                   -12.215286                 11.742682
# 4                    17.213737                -13.958878
# ...                        ...                       ...
# 4994                -14.424996                  7.055352
# 4995                -12.249485                 12.226991
# 4996                -19.242759                -18.218209
# 4997                -13.561869                  2.773022
# 4998                 -3.784030                  0.979866
#
# [4999 rows x 2 columns]
#       -7.262173392018990370e+00  9.572603824406265005e+00
# 0                      3.462140                 10.684524
# 1                    -12.996801                 -3.446163
# 2                      7.083537                -14.074146
# ...

# %%
#choose the linear regression model
model = LinearRegression(fit_intercept = True)

# %%
# fitting the model 
model.fit(X,y)
# Out:
# LinearRegression()

# %%
training_datamodel = model.predict(X)

# %%
from sklearn import metrics 
train_error_score = metrics.r2_score(y, training_datamodel) 
print("R squared Error - Training : ", train_error_score)
# Out:
# R squared Error - Training :  0.9924292853694737

# %%
model.fit(X1,y1)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X1)
test_error =metrics.r2_score(y1,y_pred)
print("R squared Error - Test : ", test_error)
# Out:
# R squared Error - Test :  0.9926863790551842

# %%
sns.regplot(x=y1,y=y_pred, scatter_kws={"color": "green"}, line_kws={"color": "blue"})
# Out:
# <Axes: xlabel='-3.756792885773750612e+01'>
